# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# It includes the analysis of the Turkey-based earthquake natural disaster dated February 6, 2023, based on COPERNICUS data.
# </p>
# </div>
#     </h4>

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# This is a sequel. It is aimed to reveal the effects of the earthquake on cities basis.
# </p>
# </div>
#     </h4>

# %% [markdown]
# # Libraries / Kütüphaneler

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#000000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# LIBRARIES
# </p>
# </div>
#     </h4>

# %%
import pandas as pd
import numpy as np

# %%
import json
import os

# %%
import folium
from folium import plugins
import plotly.express as px
import matplotlib.pyplot as plt

# %% [markdown]
# # Class Outputs / Sınıf Çıktıları

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#000000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# CLASS OUTPUTS
# </p>
# </div>
#     </h4>

# %%
class PARAMETERS:
    pass
class CLASSINIT:
    pass
class RESULTS:
    pass
class ACTIVATION:
    pass

# %%
stateerror = "[DENIED - PLEASE USE FOR SCIENTIFIC APPROACHES]"

# %% [markdown]
# # Cities Files / Şehir Dosyaları

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#000000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# CITIES FILES
# </p>
# </div>
#     </h4>

# %% [markdown]
# #### Dictionary Lists / Sözlük Listeleri

# %%
cdict = {"ADIYAMAN":[],
        "AFSIN":[],
        "ANTAKYA":[],
        "BAHCE":[],
        "DIYARBAKIR":[],
        "DUZICI":[],
        "ELBISTAN":[],
        "ERDEMOGLU":[],
        "GAZIANTEP":[],
        "GOLBASI":[],
        "ISLAHIYE":[],
        "KAHRAMANMARAS":[],
        "KIRIKHAN":[],
        "MALATYA":[],
        "OSMANIYE":[],
        "PAZARCIK":[],
        "SANLIURFA":[],
        "TURKOGLU":[]}

# %% [markdown]
# #### Embedding Data in Lists / Verileri Listelere Gömmek

# %%
class DICTOFCITIES(object):
    def __init__(self)->CLASSINIT:
        self.maindirectory = "/kaggle/input/feb-06-23earthquake-turkey-citiesvectors/vectors"
    def __str__(self)->str:
        return "DICTIONARY OF CITIES FOR DATA EMBEDDING - SUBPROCESS"
    def __call__(self)->None:
        return None
    def __getstate__(self)->CLASSINIT:
        raise TypeError(stateerror)
    def __repr__(self)->str:
        return DICTOFCITIES.__doc__
    def _EMBED(self,ct:str,bt:str,bt2:str,mty:str,ty:str,dc:dict)->PARAMETERS:
        for r,d,f in os.walk(self.maindirectory):
            for n in f:
                if (ct in os.path.join(r,n)) and (bt in os.path.join(r,n) or bt2 in os.path.join(r,n)) and (mty in os.path.join(r,n)) and (ty in os.path.join(r,n)):
                    dc[ct.upper()].append(os.path.join(r,n))
                else:
                    pass
    def _LAUNCH(self,bt:str,bt2:str,mty:str,ty:str,dc:dict)->RESULTS:
        for xkey in dc.keys():
            self._EMBED(xkey,bt,bt2,mty,ty,dc)

# %%
DICTOFCITIES()._LAUNCH("builtUpA","builtUpP","M1_V1","json",cdict)

# %%
maindictlen = len(cdict)
print(f"FIRST LENGTH: {maindictlen}")
# Out:
# FIRST LENGTH: 18

# %%
controlkey = []
for xkey,xvalue in cdict.items():
    if len(xvalue) == 0:
        controlkey.append(xkey)

# %%
for ct in controlkey:
    del cdict[ct]

# %%
newdictlen = len(cdict)
print(f"SECOND LENGTH: {newdictlen}")
# Out:
# SECOND LENGTH: 0

# %%
if maindictlen==newdictlen:
    print("NOTHING HAS BEEN DELETED")
else:
    print("SOME NULL POINTS ARE DETECTED - NOW [DELETED]")
# Out:
# SOME NULL POINTS ARE DETECTED - NOW [DELETED]

# %% [markdown]
# #### Creating Data Frame / Veri Dosyası Yaratmak

# %%
dframe = pd.DataFrame(cdict)

# %%
dfcopy = dframe.copy()

# %% [markdown]
# #### Reading Data / Verileri Okumak

# %%
class READDATA(object):
    def __init__(self)->CLASSINIT:
        self.adiyaman = []
        self.bahce = []
        self.diyarbakir = []
        self.duzce = []
        self.elbistan = []
        self.erdemoglu = []
        self.gaziantep = []
        self.golbasi = []
        self.islahiye = []
        self.kahramanmaras = []
        self.pazarcik = []
    def __str__(self)->str:
        return "READING DATA - SUBPROCESS"
    def __call__(self)->None:
        return None
    def __getstate__(self)->CLASSINIT:
        raise TypeError(stateerror)
    def _RUN(self,
             dfdt:classmethod,
             v:int=0)->PARAMETERS:
        clm = dfdt.columns
        for xc in clm:
            with open(dfdt[str(xc)].values[v]) as pread:
                js = json.load(pread)
                for l in range(len(js["features"])):
                    if xc == "ADIYAMAN":
                        self.adiyaman.append((js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "BAHCE":
                        self.bahce.append((   js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "DIYARBAKIR":
                        self.diyarbakir.append((js["features"][l]["properties"]["name"],
                                                js["features"][l]["properties"]["notation"],
                                                js["features"][l]["properties"]["damage_gra"],
                                                js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "DUZICI":
                        self.duzce.append((   js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "ELBISTAN":
                        self.elbistan.append((js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "ERDEMOGLU":
                        self.erdemoglu.append((js["features"][l]["properties"]["name"],
                                               js["features"][l]["properties"]["notation"],
                                               js["features"][l]["properties"]["damage_gra"],
                                               js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "GAZIANTEP":
                        self.gaziantep.append((js["features"][l]["properties"]["name"],
                                               js["features"][l]["properties"]["notation"],
                                               js["features"][l]["properties"]["damage_gra"],
                                               js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "GOLBASI":
                        self.golbasi.append(( js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "ISLAHIYE":
                        self.islahiye.append((js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "KAHRAMANMARAS":
                        self.kahramanmaras.append((js["features"][l]["properties"]["name"],
                                                   js["features"][l]["properties"]["notation"],
                                                   js["features"][l]["properties"]["damage_gra"],
                                                   js["features"][l]["geometry"]["coordinates"]))
                    elif xc == "PAZARCIK":
                        self.pazarcik.append((js["features"][l]["properties"]["name"],
                                              js["features"][l]["properties"]["notation"],
                                              js["features"][l]["properties"]["damage_gra"],
                                              js["features"][l]["geometry"]["coordinates"]))
                    else:
                        pass

# %%
rd = READDATA()
rd._RUN(dframe)

# %%
lplist = [rd.adiyaman,
         rd.bahce,
         rd.diyarbakir,
         rd.duzce,
         rd.elbistan,
         rd.erdemoglu,
         rd.gaziantep,
         rd.golbasi,
         rd.islahiye,
         rd.kahramanmaras,
         rd.pazarcik]
lpname = ["adiyaman",
         "bahce",
         "diyarbakir",
         "duzce",
         "elbistan",
         "erdemoglu",
         "gaziantep",
         "golbasi",
         "islahiye",
         "kahramanmaras",
         "pazarcik"]

# %% [markdown]
# #### Coordinates & Features / Koordinatlar & Özellikler

# %%
class BASEDONCOORDINATE(object):
    def __init__(self)->CLASSINIT:
        pass
    def __str__(self)->str:
        return "COORDINATES & FEATURES - SUBPROCESS"
    def __call__(self)->None:
        return None
    def __getstate__(self)->CLASSINIT:
        raise TypeError(stateerror)
    def __repr__(self)->str:
        return BASEDONCOORDINATE.__doc__
    def _RETURNCOORDINATE(self,
                          lparams:list or tuple,
                          listlat:list,
                          listlon:list)->RESULTS:
        lenparams = len(lparams)
        cntparams = len(lparams[0][3])
        if cntparams == 2:
            for xl in range(lenparams):
                    latx = lparams[xl][3][0]
                    lonx = lparams[xl][3][1]
                    listlat.append(latx)
                    listlon.append(lonx)
        else:
            pass
    def _RETURNZIPCOORDINATES(self,
                             lparams:list or tuple,
                             listlat:list,
                             listlon:list)->RESULTS:
        lt,ln = self._RETURNCOORDINATE(lparams,listlat,listlon)
        return list(zip(lt,ln))
    def _RETURNALLATTRIBUTES(self,
                            lparams:list or tuple,
                            nmtarget:str)->RESULTS:
        nmatt = []
        tyatt = []
        dmatt = []
        ltlat = []
        ltlon = []
        lenparams = len(lparams)
        cntparams = len(lparams[0][3])
        if cntparams == 2:
            for xl in range(lenparams):
                nmatt.append(lparams[xl][0])
                tyatt.append(lparams[xl][1])
                dmatt.append(lparams[xl][2])
                latx = lparams[xl][3][0]
                lonx = lparams[xl][3][1]
                ltlat.append(latx)
                ltlon.append(lonx)
            nseries = pd.Series(nmatt)
            tseries = pd.Series(tyatt)
            dseries = pd.Series(dmatt)
            ltseries = pd.Series(ltlat)
            lnseries = pd.Series(ltlon)
            fr = {"BUILDING_NAME":nseries,
                 "BUILDING_TYPE":tseries,
                 "DAMAGED_TYPE":dseries,
                 "LATITUDE":ltseries,
                 "LONGITUDE":lnseries}
            rs = pd.DataFrame(fr)
            rs.to_csv(f"{nmtarget}.csv")
            return rs
        else:
            pass

# %% [markdown]
# #### Saving New Data / Yeni Veriyi Kaydetme

# %%
for _ly,_ln in zip(lplist,lpname):
    _ = BASEDONCOORDINATE()._RETURNALLATTRIBUTES(_ly,_ln)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 for _ly,_ln in zip(lplist,lpname):
# ----> 2     _ = BASEDONCOORDINATE()._RETURNALLATTRIBUTES(_ly,_ln)
#
# Cell In[24], line 41, in BASEDONCOORDINATE._RETURNALLATTRIBUTES(self, lparams, nmtarget)
#      39 ltlon = []
#      40 lenparams = len(lparams)
# ---> 41 cntparams = len(lparams[0][3])
#      42 if cntparams == 2:
#      43     for xl in range(lenparams):
#
# IndexError: list index out of range

# %% [markdown]
# # Map / Harita

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#000000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# MAP
# </p>
# </div>
#     </h4>

# %% [markdown]
# #### Lists / Listeler

# %%
tilelayers = {"OCEAN_BASE":"http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Base",
              "NAVIGATION_CHART":"http://services.arcgisonline.com/ArcGIS/rest/services/Specialty/World_Navigation_Charts",
              "OCEAN_REFERENCE":"http://services.arcgisonline.com/arcgis/rest/services/Ocean/World_Ocean_Reference",
              "NAT_GEO":"http://services.arcgisonline.com/arcgis/rest/services/NatGeo_World_Map/MapServer",
              "IMAGERY":"http://services.arcgisonline.com/arcgis/rest/services/World_Imagery/MapServer",
              "PHYSICAL":"http://services.arcgisonline.com/arcgis/rest/services/World_Physical_Map/MapServer",
              "SHADED_RELIEF":"http://services.arcgisonline.com/arcgis/rest/services/World_Shaded_Relief/MapServer",
              "STREET":"http://services.arcgisonline.com/arcgis/rest/services/World_Street_Map/MapServer",
              "TERRAIN_BASE":"http://services.arcgisonline.com/arcgis/rest/services/World_Terrain_Base/MapServer",
              "TOPOGRAPHIC":"http://services.arcgisonline.com/arcgis/rest/services/World_Topo_Map/MapServer",
              "DELORME":"https://services.arcgisonline.com/arcgis/rest/services/Specialty/DeLorme_World_Base_Map/MapServer",
              "DARK":"https://services.arcgisonline.com/arcgis/rest/services/Canvas/World_Dark_Gray_Base/MapServer",
              "LIGHT":"https://services.arcgisonline.com/arcgis/rest/services/Canvas/World_Light_Gray_Base/MapServer",
              "HILLSHADE":"https://services.arcgisonline.com/arcgis/rest/services/Elevation/World_Hillshade/MapServer",
              "BOUND_PLACE":"https://services.arcgisonline.com/arcgis/rest/services/Reference/World_Boundaries_and_Places/MapServer",
              "TRANSPORTATION":"https://services.arcgisonline.com/arcgis/rest/services/Reference/World_Transportation/MapServer"}

# %% [markdown]
# #### Functions / Fonksiyonlar

# %%
class RETURNMAP(object):
    def __init__(self)->CLASSINIT:
        self.__lc = [38,35]
        self.__zm = 5
        self.__tl = "Stamen Terrain"
        self.__ml = "/MapServer/tile/{z}/{y}/{x}"
    def __str__(self)->str:
        return "RETURN MAP - SUBPROCESS"
    def __call__(self)->None:
        return None
    def __getstate__(self)->CLASSINIT:
        raise TypeError(stateerror)
    def __repr__(self)->str:
        return RETURNMAP.__doc__
    def _GETSAMPLE(self)->RESULTS:
        mf = folium.Map(tiles=self.__tl,
                       location=self.__lc,
                       zoom_start=self.__zm,
                       attr="<p>EQ - RESEARCH</p>")
        return mf
    def _INITLAYER(self,mp:classmethod)->RESULTS:
        for _xn,_xt in tilelayers.items():
            _xt += self.__ml
            folium.TileLayer(tiles=_xt,
                            name=_xn,
                            attr=f"<p>{_xn.upper()} TYPE - EQ</p>").add_to(mp)
        folium.LayerControl().add_to(mp)
        mp.add_child(folium.LatLngPopup())
        mp.add_child(plugins.Geocoder())
        return mp
    def _LOCAL(self,
              mp:classmethod,
              dp:classmethod,
              cause:str,
              coor:list)->RESULTS:
        for xcount,xtarget in enumerate(coor):
            ifr = f"""
            <html>
            <h6>TARGET: {cause}</h6>
            <div>
            <p>
            BUILDING NAME:
            </p>
            <p>
            <b>{dp.BUILDING_NAME.values[xcount]}</b>
            </p>
            <p>
            DAMAGED:
            </p>
            <p>
            <b>{dp.DAMAGED_TYPE.values[xcount]}</b>
            </p>
            <p>
            COORDINATES:
            </p>
            <p>
            <b>{str(round(xtarget[0],3))}, {str(round(xtarget[1],3))}</b>
            </p>
            </div>
            </html>
            """
            ipop = folium.Popup(folium.IFrame(ifr),
                               min_width=200,
                               max_width=200)
            icn = folium.Icon(color="red",icon="glyphicon-flag")
            folium.Marker(location=[xtarget[0],xtarget[1]],
                         popup=ipop,
                         tooltip="Check",
                         icon=icn).add_to(mp)
    def _ALLRUN(self,
               dp:classmethod,
               cause:str,
               coor:list)->RESULTS:
        mapbase = self._GETSAMPLE()
        self._LOCAL(mapbase,dp,cause,coor)
        mnew = self._INITLAYER(mapbase)
        return mnew

# %% [markdown]
# #### GOLBASI

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE GOLBASI LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/golbasi.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "GOLBASI",
                           cret)
mret
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dret = pd.read_csv(f"/kaggle/working/golbasi.csv")
#       2 cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
#       3                 dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
#       4 mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
#       5                            "GOLBASI",
#       6                            cret)
#
# File ~/anaconda3/envs/tfm/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### BAHCE

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE BAHCE LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/bahce.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Damaged"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Damaged"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Damaged"],
                           "BAHCE",
                           cret)
mret
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 dret = pd.read_csv(f"/kaggle/working/bahce.csv")
#       2 cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Damaged"].LATITUDE,
#       3                 dret[dret["DAMAGED_TYPE"]=="Damaged"].LONGITUDE))
#       4 mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Damaged"],
#       5                            "BAHCE",
#       6                            cret)
#
# File ~/anaconda3/envs/tfm/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### DUZCE

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE DUZCE LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/duzce.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "DUZCE",
                           cret)
mret
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 dret = pd.read_csv(f"/kaggle/working/duzce.csv")
#       2 cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
#       3                 dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
#       4 mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
#       5                            "DUZCE",
#       6                            cret)
#
# File ~/anaconda3/envs/tfm/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### PAZARCIK

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE PAZARCIK LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/pazarcik.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "PAZARCIK",
                           cret)
mret
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dret = pd.read_csv(f"/kaggle/working/pazarcik.csv")
#       2 cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
#       3                 dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
#       4 mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
#       5                            "PAZARCIK",
#       6                            cret)
#
# File ~/anaconda3/envs/tfm/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# #### KAHRAMANMARAS

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE KAHRAMANMARAS LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/kahramanmaras.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "KAHRAMANMARAS",
                           cret)
mret
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### ERDEMOGLU

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE ERDEMOGLU LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/erdemoglu.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "ERDEMOGLU",
                           cret)
mret
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### ELBISTAN

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE ELBISTAN LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/elbistan.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "ELBISTAN",
                           cret)
mret
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### GAZIANTEP

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# CONTAINS MAPPING OF THE GAZIANTEP LOCATION
# </p>
# </div>
#     </h4>

# %%
dret = pd.read_csv(f"/kaggle/working/gaziantep.csv")
cret = list(zip(dret[dret["DAMAGED_TYPE"]=="Destroyed"].LATITUDE,
                dret[dret["DAMAGED_TYPE"]=="Destroyed"].LONGITUDE))
mret = RETURNMAP()._ALLRUN(dret[dret["DAMAGED_TYPE"]=="Destroyed"],
                           "GAZIANTEP",
                           cret)
mret
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Analysis / Analiz

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#000000;
#            font-size:80%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 40px;
#               color:white;">
# ANALYSIS
# </p>
# </div>
#     </h4>

# %%
namecitylist = ["gaziantep",
                "elbistan",
                "erdemoglu",
                "bahce",
                "pazarcik",
                "golbasi",
                "kahramanmaras",
                "duzce"]

# %%
sllist = ["Destroyed","Possibly damaged","Damaged"]

# %%
class ANALYSISCITIES(object):
    def __init__(self)->CLASSINIT:
        pass
    def __str__(self)->str:
        return "ANALYSIS FOR CITIES - SUBPROCESS"
    def __call__(self)->None:
        return None
    def __getstate__(self)->CLASSINIT:
        raise TypeError(stateerror)
    def __repr__(self)->str:
        return ANALYSISCITIES.__doc__
    def _HISTOGRAM(self,
                   dt:classmethod,
                   xval:str,
                   stitle:str,
                   clr:str,
                   tmp:str="plotly_dark")->RESULTS:
        fg = px.histogram(dt,
                         xval,
                         color=clr,
                         title=f"<b>{stitle}</b>",
                         template=tmp)
        fg.update_traces(textposition='inside',
                          textfont_size=8)
        fg.update_layout(bargap=0.2)
        fg.show()
    def _JUSTTOTAL(self,dt:classmethod,compm:str):
        return len(dt[compm].values)
    def _PERCENTAGE(self,
                   dt:classmethod,
                   compm:str,
                   comp1:str)->RESULTS:
        totallen = len(dt[compm].values)
        targetlen = len(dt[dt[compm] == comp1])
        perc = f"[ {100 * (targetlen/totallen)} ] % WAS [ {comp1.upper()} ]"
        cmtx = f"TOTAL: [ {targetlen} ] WAS [ {comp1.upper()} ]"
        return perc,cmtx
    def _ALLTOTAL(self,
                 dt:classmethod,
                 compm:str,
                 comp1:str,
                 lt:int)->RESULTS:
        totallen = len(dt[compm].values)
        targetlen = len(dt[dt[compm] == comp1])
        lt += targetlen
        return lt

# %% [markdown]
# #### Results - Histogram / Sonuçlar - Histogram

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# HISTOGRAM BASED ANALYSIS
# </p>
# </div>
#     </h4>

# %%
for xnme in namecitylist:
    bls = pd.read_csv(f"/kaggle/working/{xnme}.csv")
    ANALYSISCITIES()._HISTOGRAM(bls,"DAMAGED_TYPE",xnme.upper(),"BUILDING_TYPE")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# #### Results - Percentage / Sonuçlar - Yüzdelik

# %% [markdown]
# <h4>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#200000;
#            font-size:90%;
#            font-family:Verdana;
#            letter-spacing:0.7px">
#
# <p style="padding: 50px;
#               color:white;">
# NUMERIC BASED ANALYSIS
# </p>
# </div>
#     </h4>

# %%
for xnme in namecitylist:
    bls = pd.read_csv(f"/kaggle/working/{xnme}.csv")
    print(f"\nFOR {xnme.upper()}\n")
    tpl = ANALYSISCITIES()._JUSTTOTAL(bls,"DAMAGED_TYPE")
    print(f"TOTAL BUILDINGS OBSERVATIONS --> {tpl}\n")
    for xtarval in sllist:
        res,cmt = ANALYSISCITIES()._PERCENTAGE(bls,"DAMAGED_TYPE",xtarval)
        print(f"RESULTS:\n\n{cmt}\n{res}\n{'---'*7}\n")
    print("###########"*7)
# Out:
# FOR GAZIANTEP
#
# TOTAL BUILDINGS OBSERVATIONS --> 10960
#
# RESULTS:
#
# TOTAL: [ 44 ] WAS [ DESTROYED ]
# [ 0.40145985401459855 ] % WAS [ DESTROYED ]
# ---------------------
#
# RESULTS:
#
# TOTAL: [ 19 ] WAS [ POSSIBLY DAMAGED ]
# [ 0.17335766423357665 ] % WAS [ POSSIBLY DAMAGED ]
# ---------------------
#
# RESULTS:
#
# TOTAL: [ 9 ] WAS [ DAMAGED ]
# [ 0.08211678832116788 ] % WAS [ DAMAGED ]
# ---------------------
#
# #############################################################################
#
# FOR ELBISTAN
#
# TOTAL BUILDINGS OBSERVATIONS --> 439
#
# RESULTS:
#
# TOTAL: [ 95 ] WAS [ DESTROYED ]
# [ 21.64009111617312 ] % WAS [ DESTROYED ]
# ---------------------
#
# RESULTS:
#
# TOTAL: [ 130 ] WAS [ POSSIBLY DAMAGED ]
# [ 29.6127562642369 ] % WAS [ POSSIBLY DAMAGED ]
# ---------------------
#
# RESULTS:
#
# TOTAL: [ 64 ] WAS [ DAMAGED ]
# [ 14.578587699316628 ] % WAS [ DAMAGED ]
# ---------------------
#
# ...

# %%
ltdes = 0
ltpde = 0
ltdam = 0
for xnme in namecitylist:
    bls = pd.read_csv(f"/kaggle/working/{xnme}.csv")
    for xtarval in sllist:
        if xtarval == "Destroyed":
            ltdes = ANALYSISCITIES()._ALLTOTAL(bls,"DAMAGED_TYPE",xtarval,ltdes)
        elif xtarval == "Possibly damaged":
            ltpde = ANALYSISCITIES()._ALLTOTAL(bls,"DAMAGED_TYPE",xtarval,ltpde)
        elif xtarval == "Damaged":
            ltdam = ANALYSISCITIES()._ALLTOTAL(bls,"DAMAGED_TYPE",xtarval,ltdam)
        else:
            pass
print(f"DESTROYED TOTAL: {ltdes}")
print(f"POSSIBLY DAMAGED TOTAL: {ltpde}")
print(f"DAMAGED TOTAL: {ltdam}")
print(f"BADLY AFFECTED PLACES TOTAL: {ltdes+ltpde+ltdam}")
# Out:
# DESTROYED TOTAL: 475
# POSSIBLY DAMAGED TOTAL: 826
# DAMAGED TOTAL: 303
# BADLY AFFECTED PLACES TOTAL: 1604
