# %% [markdown]
# <a name="top"> <h1>04. Modeling and Interpretation Using PyCaret </h1> <a>
#
# <p>Geospatial Analysis of the 2023 Earthquakes in Turkey<br />
# <strong>Master Thesis</strong><br />
# <strong>Master of Data Science</strong></p>
#
#
# <p style="text-align:right">Gozde Yazganoglu (<em>gozde.yazganoglu@cunef.edu</em>)</p>

# %% [markdown]
# <a class="anchor" id="0.1"></a>
#
# ## Table of Contents
#
# 1. [Introduction](#1)
# 1. [Importing libraries](#2)
# 1. [Reading the data and Profiling](#3)
# 1. [Variables](#4)
# 1. [Visualization of the result of geostatistical data interpolation](#5)
# 1. [Saving data for other notebooks](#6)

# %% [markdown]
# ## 1. Introduction <a class="anchor" id="1"></a>
#
# [Back to Table of Contents](#0.1)
#
#
# Back then in previous 4 notebooks we have done most of the geospatial analisis and had some insights about geographic properties. However keeping an environment with geopandas is very hard with more libraries such as pycaret. For this reason we are going to examine in this notebook a pandas dataframe that has geographic variables and try to understand what affects the most damage_gra.
#
# Pycaret is a low code machine learning tool that helps us deploy, compare, optimize and interepret the model with just a few lines of codes. Even though we do not use a lot of code it is not very hard to adjust it to our needs either. The most important functions, classes we use in pycaret could be listed as follows.
#
#
#     ClassificationExperiment,
#     setup,
#     compare_model,
#     tune_model,
#     interpret_model

# %% [markdown]
# ## 2. Importing libraries  and Reading the Data <a class="anchor" id="2"></a>
#
# [Back to Table of Contents](#0.1)
#
# In this notebook we are using new_pycaret.yaml. In order to run local this environment should be installed.
#
# In this notebook we use a basic pandas library in order not to have problems with the environment. However data reserves geographic information such as latitude, longitude, lags and distances. Our hypothesis is this variables are important in magnitude in order we to predict the damage_gra after the disaster.

# %%
#importing libraries from new_pycaret environment
from pycaret.classification import *
from pycaret.regression import *
import pandas as pd
import pickle
import numpy as np

# %%
#reading pandas dataframe
data = pd.read_csv('../data/processed/df.csv')

# %%
data
# Out:
#                            obj_type                       info  damage_gra  \
# 0          11_RESIDENTIAL_BUILDINGS         997_NOT_APPLICABLE           1
# 1          11_RESIDENTIAL_BUILDINGS         997_NOT_APPLICABLE           1
# 2      12_NON_RESIDENTIAL_BUILDINGS  1251_INDUSTRIAL_BUILDINGS           1
# 3      12_NON_RESIDENTIAL_BUILDINGS  1251_INDUSTRIAL_BUILDINGS           1
# 4          11_RESIDENTIAL_BUILDINGS         997_NOT_APPLICABLE           1
# ...                             ...                        ...         ...
# 98790                  212_RAILWAYS         997_NOT_APPLICABLE           1
# 98791                  212_RAILWAYS         997_NOT_APPLICABLE           1
# 98792                  212_RAILWAYS         997_NOT_APPLICABLE           1
# 98793                  212_RAILWAYS         997_NOT_APPLICABLE           1
# 98794                  212_RAILWAYS         997_NOT_APPLICABLE           1
#
#        locality  population  income  total_sales  second_sales  water_access  \
# 0      ADIYAMAN      316140    4092        40087         20574          0.98
# 1      ADIYAMAN      316140    4092        40087         20574          0.98
# 2      ADIYAMAN      316140    4092        40087         20574          0.98
# 3      ADIYAMAN      316140    4092        40087         20574          0.98
# 4      ADIYAMAN      316140    4092        40087         20574          0.98
# ...         ...         ...     ...          ...           ...           ...
# 98790  TURKOGLU       78976    5997         1938           536          0.95
# 98791  TURKOGLU       78976    5997         1938           536          0.95
# 98792  TURKOGLU       78976    5997         1938           536          0.95
# 98793  TURKOGLU       78976    5997         1938           536          0.95
# 98794  TURKOGLU       78976    5997         1938           536          0.95
#
#        elec_cons  ...  std_lag_nearest_camping_distance  \
# 0           2060  ...                         -0.336509
# 1           2060  ...                         -0.338395
# 2           2060  ...                         -0.319254
# 3           2060  ...                         -0.318057
# 4           2060  ...                         -0.339910
# ...          ...  ...                               ...
# 98790       4343  ...                         -0.364657
# 98791       4343  ...                         -0.364976
# 98792       4343  ...                         -0.364853
# 98793       4343  ...                         -0.364460
# 98794       4343  ...                         -0.364288
#
#        lag_nearest_earthquake_distance  std_nearest_earthquake_distance  \
# 0                             1.121437                         0.823108
# 1                             1.121020                         0.821473
# 2                             1.126003                         0.829966
# 3                             1.126158                         0.831173
# 4                             1.120674                         0.820239
# ...                                ...                              ...
# 98790                         0.092105                        -1.097597
# 98791                         0.092183                        -1.098330
# 98792                         0.092170                        -1.098204
# 98793                         0.092054                        -1.097125
# 98794                         0.092011                        -1.096724
#
#        std_lag_nearest_earthquake_distance  lag_nearest_fault_distance  \
# 0                                 0.822247                    0.017026
# 1                                 0.821468                    0.017263
# 2                                 0.830761                    0.014187
# 3                                 0.831050                    0.014298
# 4                                 0.820823                    0.017477
# ...                                    ...                         ...
# 98790                            -1.097274                    0.031475
# 98791                            -1.097127                    0.031408
# 98792                            -1.097152                    0.031503
# 98793                            -1.097368                    0.031509
# 98794                            -1.097448                    0.031543
#
#        std_nearest_fault_distance  std_lag_nearest_fault_distance  \
# 0                       -1.708649                       -1.707721
# 1                       -1.703229                       -1.705170
# 2                       -1.733850                       -1.738174
# 3                       -1.737541                       -1.736986
# 4                       -1.699083                       -1.702874
# ...                           ...                             ...
# 98790                   -1.551232                       -1.552713
# 98791                   -1.547625                       -1.553434
# 98792                   -1.552762                       -1.552407
# 98793                   -1.553062                       -1.552347
# 98794                   -1.554889                       -1.551981
#
#        lag_damage_gra  std_damage_gra  std_lag_damage_gra
# 0                 1.0       -0.208399             -0.2745
# 1                 1.0       -0.208399             -0.2745
# 2                 1.0       -0.208399             -0.2745
# 3                 1.0       -0.208399             -0.2745
# 4                 1.0       -0.208399             -0.2745
# ...               ...             ...                 ...
# 98790             1.0       -0.208399             -0.2745
# 98791             1.0       -0.208399             -0.2745
# 98792             1.0       -0.208399             -0.2745
# 98793             1.0       -0.208399             -0.2745
# 98794             1.0       -0.208399             -0.2745
#
# [98795 rows x 54 columns]

# %% [markdown]
# We eliminated the class "damage_gra = 0" since it represents buildings whose status is unknown to us. We also remove 'percentage' as it is directly related to the damage_gra value.

# %%
#Remowing the 0 damage grade

data = data[data['damage_gra'] != 0]

data.groupby('damage_gra').count()

#removing percentage since it is directly correlated with damage grade

#data.drop('percentage', axis=1, inplace=True)

data.tail()
# Out:
#            obj_type                info  damage_gra  locality  population  \
# 98790  212_RAILWAYS  997_NOT_APPLICABLE           1  TURKOGLU       78976
# 98791  212_RAILWAYS  997_NOT_APPLICABLE           1  TURKOGLU       78976
# 98792  212_RAILWAYS  997_NOT_APPLICABLE           1  TURKOGLU       78976
# 98793  212_RAILWAYS  997_NOT_APPLICABLE           1  TURKOGLU       78976
# 98794  212_RAILWAYS  997_NOT_APPLICABLE           1  TURKOGLU       78976
#
#        income  total_sales  second_sales  water_access  elec_cons  ...  \
# 98790    5997         1938           536          0.95       4343  ...
# 98791    5997         1938           536          0.95       4343  ...
# 98792    5997         1938           536          0.95       4343  ...
# 98793    5997         1938           536          0.95       4343  ...
# 98794    5997         1938           536          0.95       4343  ...
#
#        std_lag_nearest_camping_distance  lag_nearest_earthquake_distance  \
# 98790                         -0.364657                         0.092105
# 98791                         -0.364976                         0.092183
# 98792                         -0.364853                         0.092170
# 98793                         -0.364460                         0.092054
# 98794                         -0.364288                         0.092011
#
#        std_nearest_earthquake_distance  std_lag_nearest_earthquake_distance  \
# 98790                        -1.097597                            -1.097274
# 98791                        -1.098330                            -1.097127
# 98792                        -1.098204                            -1.097152
# 98793                        -1.097125                            -1.097368
# 98794                        -1.096724                            -1.097448
#
#        lag_nearest_fault_distance  std_nearest_fault_distance  \
# 98790                    0.031475                   -1.551232
# 98791                    0.031408                   -1.547625
# 98792                    0.031503                   -1.552762
# 98793                    0.031509                   -1.553062
# 98794                    0.031543                   -1.554889
#
#        std_lag_nearest_fault_distance  lag_damage_gra  std_damage_gra  \
# 98790                       -1.552713             1.0       -0.208399
# 98791                       -1.553434             1.0       -0.208399
# 98792                       -1.552407             1.0       -0.208399
# 98793                       -1.552347             1.0       -0.208399
# 98794                       -1.551981             1.0       -0.208399
#
#        std_lag_damage_gra
# 98790             -0.2745
# 98791             -0.2745
# 98792             -0.2745
# 98793             -0.2745
# 98794             -0.2745
#
# [5 rows x 53 columns]

# %% [markdown]
# In PyCaret, there are two primary approaches to implementation. One can either instantiate a Classification object (as referenced in the API documentation), or one can directly utilize functions like setup among others.
#
# The setup function in PyCaret is the initial step to setting up any experiment, and it essentially prepares the data for further analysis and modeling. Here's a bit more detail:
#
#     Data Preprocessing:
# setup takes care of many preprocessing tasks. These include handling missing values, transforming categorical variables into numeric (via one-hot encoding or label encoding), and splitting the dataset into training and test sets.
#
#     Pipeline Creation:
# When you use setup, PyCaret internally creates a pipeline that processes the data. This pipeline can then be used seamlessly with other PyCaret functions.
#
#     Customization:
# You can customize how the setup function behaves by using its many parameters. For example, you can specify the ratio of the train/test split, choose to ignore certain features, select specific normalization methods, etc.
#
#     Environment Setup:
# It initializes the environment in such a way that all the functions of PyCaret can work in harmony. This means the algorithms, transformations, and configurations you choose while setting up will be consistent throughout your experiment.
#
#     Informative Display:
# Once the setup function is run, it displays an informative grid that shows key details like the number of features, the number of samples, the transformation methods being used, and more.
#
#     Flexibility:
# While setup does automate a lot of tasks, it doesn't take away your control. If you disagree with a preprocessing step it took, you can modify it using its parameters.
#
# In essence, the setup function in PyCaret is your entry point into the library's streamlined workflow, taking care of a lot of the groundwork so you can focus on building and tuning your models.
#
# In the following code, we've employed feature selection. Using PyCaret has notably reduced our coding effort compared to scikit-learn.

# %%
session = 123

s = ClassificationExperiment()

s.setup(data = data, 
        target = 'damage_gra', 
        session_id = session,
        feature_selection= True,
        
        feature_selection_method= 'classic',
      
        ) 


best = s.compare_models()
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5428
# [LightGBM] [Info] Number of data points in the train set: 68790, number of used features: 75
# [LightGBM] [Info] Start training from score -0.057225
# [LightGBM] [Info] Start training from score -3.889599
# [LightGBM] [Info] Start training from score -3.853993
# [LightGBM] [Info] Start training from score -4.270839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# <style type="text/css">
# #T_00571_row10_col1, #T_00571_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_00571">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00571_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_00571_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00571_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00571_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_00571_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00571_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_00571_row1_col1" class="data row1 col1" >damage_gra</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00571_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_00571_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00571_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_00571_row3_col1" class="data row3 col1" >1: 0, 2: 1, 3: 2, 4: 3</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00571_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_00571_row4_col1" class="data row4 col1" >(98272, 53)</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00571_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_00571_row5_col1" class="data row5 col1" >(98272, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00571_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_00571_row6_col1" class="data row6 col1" >(68790, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00571_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_00571_row7_col1" class="data row7 col1" >(29482, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00571_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_00571_row8_col1" class="data row8 col1" >49</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_00571_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_00571_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_00571_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_00571_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_00571_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_00571_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_00571_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_00571_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_00571_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_00571_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_00571_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_00571_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_00571_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_00571_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_00571_row16_col0" class="data row16 col0" >Feature selection</td>
#       <td id="T_00571_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_00571_row17_col0" class="data row17 col0" >Feature selection method</td>
#       <td id="T_00571_row17_col1" class="data row17 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_00571_row18_col0" class="data row18 col0" >Feature selection estimator</td>
#       <td id="T_00571_row18_col1" class="data row18 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_00571_row19_col0" class="data row19 col0" >Number of features selected</td>
#       <td id="T_00571_row19_col1" class="data row19 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_00571_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_00571_row20_col1" class="data row20 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_00571_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_00571_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_00571_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_00571_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_00571_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_00571_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_00571_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_00571_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_00571_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_00571_row25_col1" class="data row25 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_00571_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_00571_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_00571_row26_col1" class="data row26 col1" >9270</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             00:02:04
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
print(best)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=-1, oob_score=False,
#                        random_state=123, verbose=0, warm_start=False)

# %%
tuned_model= tune_model(best)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tuned_model= tune_model(best)
#
# File ~/anaconda3/envs/new_pycaret/lib/python3.8/site-packages/pycaret/utils/generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962 for name, message in global_names.items():
#     963     if globals_d[name] is None:
# --> 964         raise ValueError(message)
#     965 return func(*args, **kwargs)
#
# ValueError: _CURRENT_EXPERIMENT global variable is not set. Please run setup() first.

# %%
dashboard = s.dashboard(best)

# %%
graph_types = ['pipeline',
               'error',
               'learning',
               'vc',
               'feature',
               'feature_all',
               'parameter',
               
]
for graph_type in graph_types:
    s.plot_model(best, plot= graph_type)

# %%
s.predict_model(best)

# %%
s.save_model(best, 'my_best_pipeline')

# %%
interpretation_plots = ['summary', 'correlation', 'reason', 'pdp', 'msa', 'pfi']










interpretation = s.interpret_model(best, plot = 'summary')
